# %% [markdown]
# Deep Speech Implementation
# Modeling referred from https://keras.io/examples/audio/ctc_asr/

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from IPython import display
from jiwer import wer
import librosa

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install jiwer
# !pip install librosa
# Out:
# Requirement already satisfied: jiwer in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (2.3.0)
# Requirement already satisfied: python-Levenshtein==0.12.2 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from jiwer) (0.12.2)
# Requirement already satisfied: setuptools in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from python-Levenshtein==0.12.2->jiwer) (61.2.0)
# Requirement already satisfied: librosa in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (0.9.1)
# Requirement already satisfied: joblib>=0.14 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from librosa) (1.1.0)
# Requirement already satisfied: numba>=0.45.1 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from librosa) (0.55.2)
# Requirement already satisfied: packaging>=20.0 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from librosa) (21.3)
# Requirement already satisfied: pooch>=1.0 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from librosa) (1.6.0)
# Requirement already satisfied: audioread>=2.1.5 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from librosa) (2.1.9)
# Requirement already satisfied: decorator>=4.0.10 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numpy>=1.17.0 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from librosa) (1.21.5)
# Requirement already satisfied: scikit-learn>=0.19.1 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from librosa) (1.1.1)
# Requirement already satisfied: scipy>=1.2.0 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from librosa) (1.7.3)
# Requirement already satisfied: resampy>=0.2.2 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from librosa) (0.2.2)
# Requirement already satisfied: soundfile>=0.10.2 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: setuptools in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from numba>=0.45.1->librosa) (61.2.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from numba>=0.45.1->librosa) (0.38.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from packaging>=20.0->librosa) (3.0.8)
# Requirement already satisfied: appdirs>=1.3.0 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from pooch>=1.0->librosa) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.5.18.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: six>=1.3 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from resampy>=0.2.2->librosa) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from scikit-learn>=0.19.1->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from soundfile>=0.10.2->librosa) (1.15.0)
# Requirement already satisfied: pycparser in /home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)

# %%
train_path = '/home/teddy/dev/learning/10 academy/working/week4/ALFFA_PUBLIC/ASR/AMHARIC/data/train/'
test_path = '/home/teddy/dev/learning/10 academy/working/week4/ALFFA_PUBLIC/ASR/AMHARIC/data/test/'

# %%
def tran_loader(filename):
  name_to_text = {}
  with open (filename, encoding="utf-8")as f:
    f.readline()
    for line in f:
      name=line.split("</s>")[1]
      name=name.replace('(', '')
      name=name.replace(')', '')
      name=name.replace('\n','')
      name=name.replace(' ','')
      text=line.split("</s>")[0]
      text=text.replace("<s>","")
      name_to_text[name]=text
    return name_to_text

# %%
train_trans = tran_loader(train_path+"trsTrain.txt")

# %%
def meta_data(trans, path ):
  target=[]
  features=[]
  filenames=[]
  duration_of_recordings=[]
  for k in trans:
    filename=path+k +".wav"
    
    try:
        audio, fs = librosa.load(filename, sr=None)
    except:
        continue
    filenames.append(filename)
    duration_of_recordings.append(float(len(audio)/fs))
   
    lable = trans[k]
    target.append(lable)
  return filenames, target,duration_of_recordings

# %%
filenames, target, duration = meta_data(train_trans, train_path+"wav/")

# %%
import pandas as pd 
data=pd.DataFrame({'key': filenames,'text': target, 'duration':duration})
data.to_csv('../data/train_corpus.csv')

# %%
metadata = pd.read_csv('../data/train_corpus.csv')

# %%
split = int(len(metadata) * 0.90)
df_train = metadata[:split]
df_val = metadata[split:]

print(f"Size of the training set: {len(df_train)}")
print(f"Size of the training set: {len(df_val)}")
# Out:
# Size of the training set: 9786
# Size of the training set: 1088

�', 'ዝ', 'ዞ', 'ዟ', 'ዠ', 'ዡ', 'ዢ', 'ዣ', 'ዤ', 'ዥ', 'ዦ', 'ዧ', 'የ', 'ዩ', 'ዪ', 'ያ', 'ዬ', 'ይ', 'ዮ', 'ደ', 'ዱ', 'ዲ', 'ዳ', 'ዴ', 'ድ', 'ዶ', 'ዷ', 'ጀ', 'ጁ', 'ጂ', 'ጃ', 'ጄ', 'ጅ', 'ጆ', 'ጇ', 'ገ', 'ጉ', 'ጊ', 'ጋ', 'ጌ', 'ግ', 'ጐ', 'ጓ', 'ጔ', 'ጠ', 'ጡ', 'ጢ', 'ጣ', 'ጤ', 'ጥ', 'ጦ', 'ጧ', 'ጨ', 'ጩ', 'ጪ', 'ጫ', 'ጬ', 'ጭ', 'ጮ', 'ጯ', 'ጰ', 'ጱ', 'ጲ', 'ጳ', 'ጴ', 'ጵ', 'ጶ', 'ጷ', 'ፀ', 'ፁ', 'ፂ', 'ፃ', 'ፄ', 'ፅ', 'ፆ', 'ፇ', 'ጸ', 'ጹ', 'ጺ', 'ጻ', 'ጼ', 'ጽ', 'ጾ', 'ጿ', 'ፈ', 'ፉ', 'ፊ', 'ፋ', 'ፌ', 'ፍ', 'ፎ', 'ፏ', 'ፐ', 'ፑ', 'ፒ', 'ፓ', 'ፔ', 'ፕ', 'ፖ', "'", '?', '!', ' '] (size =242)
# 2022-06-09 13:31:07.278829: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-09 13:31:07.411091: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-09 13:31:07.411307: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-09 13:31:07.411965: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-09 13:31:07.412912: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-09 13:31:07.413274: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-09 13:31:07.413438: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-09 13:31:08.506072: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-09 13:31:08.506322: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-09 13:31:08.506503: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-09 13:31:08.507228: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4630 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
# An integer scalar Tensor. The window length in samples.
frame_length = 256
# An integer scalar Tensor. The number of samples to step.
frame_step = 160
# An integer scalar Tensor. The size of the FFT to apply.
# If not provided, uses the smallest power of 2 enclosing frame_length.
fft_length = 384


def encode_single_sample(wav_file, label):
    ###########################################
    ##  Process the Audio
    ##########################################
    # 1. Read wav file
    file = tf.io.read_file(wav_file )
    # 2. Decode the wav file
    audio, _ = tf.audio.decode_wav(file)
    audio = tf.squeeze(audio, axis=-1)
    # 3. Change type to float
    audio = tf.cast(audio, tf.float32)
    # 4. Get the spectrogram
    spectrogram = tf.signal.stft(
        audio, frame_length=frame_length, frame_step=frame_step, fft_length=fft_length
    )
    # 5. We only need the magnitude, which can be derived by applying tf.abs
    spectrogram = tf.abs(spectrogram)
    spectrogram = tf.math.pow(spectrogram, 0.5)
    # 6. normalisation
    means = tf.math.reduce_mean(spectrogram, 1, keepdims=True)
    stddevs = tf.math.reduce_std(spectrogram, 1, keepdims=True)
    spectrogram = (spectrogram - means) / (stddevs + 1e-10)
    ###########################################
    ##  Process the label
    ##########################################
    # 7. Convert label to Lower case
    label = tf.strings.lower(label)
    # 8. Split the label
    label = tf.strings.unicode_split(label, input_encoding="UTF-8")
    # 9. Map the characters in label to numbers
    label = char_to_num(label)
    # 10. Return a dict as our model is expecting two inputs
    return spectrogram, label

# %%
wavs_path = train_path + 'wav/'
batch_size = 16
# Define the trainig dataset
train_dataset = tf.data.Dataset.from_tensor_slices(
    (list(df_train["key"]), list(df_train["text"]))
)
train_dataset = (
    train_dataset.map(encode_single_sample, num_parallel_calls=tf.data.AUTOTUNE)
    .padded_batch(batch_size)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)

# Define the validation dataset
validation_dataset = tf.data.Dataset.from_tensor_slices(
    (list(df_val["key"]), list(df_val["text"]))
)
validation_dataset = (
    validation_dataset.map(encode_single_sample, num_parallel_calls=tf.data.AUTOTUNE)
    .padded_batch(batch_size)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)

# %%
def CTCLoss(y_true, y_pred):
    # Compute the training-time loss value
    batch_len = tf.cast(tf.shape(y_true)[0], dtype="int64")
    input_length = tf.cast(tf.shape(y_pred)[1], dtype="int64")
    label_length = tf.cast(tf.shape(y_true)[1], dtype="int64")

    input_length = input_length * tf.ones(shape=(batch_len, 1), dtype="int64")
    label_length = label_length * tf.ones(shape=(batch_len, 1), dtype="int64")

    loss = keras.backend.ctc_batch_cost(y_true, y_pred, input_length, label_length)
    return loss

# %%
def build_model(input_dim, output_dim, rnn_layers=5, rnn_units=128):
    """Model similar to DeepSpeech2."""
    # Model's input
    input_spectrogram = layers.Input((None, input_dim), name="input")
    # Expand the dimension to use 2D CNN.
    x = layers.Reshape((-1, input_dim, 1), name="expand_dim")(input_spectrogram)
    # Convolution layer 1
    x = layers.Conv2D(
        filters=32,
        kernel_size=[11, 41],
        strides=[2, 2],
        padding="same",
        use_bias=False,
        name="conv_1",
    )(x)
    x = layers.BatchNormalization(name="conv_1_bn")(x)
    x = layers.ReLU(name="conv_1_relu")(x)
    # Convolution layer 2
    x = layers.Conv2D(
        filters=32,
        kernel_size=[11, 21],
        strides=[1, 2],
        padding="same",
        use_bias=False,
        name="conv_2",
    )(x)
    x = layers.BatchNormalization(name="conv_2_bn")(x)
    x = layers.ReLU(name="conv_2_relu")(x)
    # Reshape the resulted volume to feed the RNNs layers
    x = layers.Reshape((-1, x.shape[-2] * x.shape[-1]))(x)
    # RNN layers
    for i in range(1, rnn_layers + 1):
        recurrent = layers.GRU(
            units=rnn_units,
            activation="tanh",
            recurrent_activation="sigmoid",
            use_bias=True,
            return_sequences=True,
            reset_after=True,
            name=f"gru_{i}",
        )
        x = layers.Bidirectional(
            recurrent, name=f"bidirectional_{i}", merge_mode="concat"
        )(x)
        if i < rnn_layers:
            x = layers.Dropout(rate=0.5)(x)
    # Dense layer
    x = layers.Dense(units=rnn_units * 2, name="dense_1")(x)
    x = layers.ReLU(name="dense_1_relu")(x)
    x = layers.Dropout(rate=0.5)(x)
    # Classification layer
    output = layers.Dense(units=output_dim + 1, activation="softmax")(x)
    # Model
    model = keras.Model(input_spectrogram, output, name="DeepSpeech_2")
    # Optimizer
    opt = keras.optimizers.Adam(learning_rate=1e-4)
    # Compile the model and return
    model.compile(optimizer=opt, loss=CTCLoss)
    return model


# Get the model
model = build_model(
    input_dim=fft_length // 2 + 1,
    output_dim=char_to_num.vocabulary_size(),
    rnn_units=512,
)
model.summary(line_length=110)
# Out:
# Model: "DeepSpeech_2"
# ______________________________________________________________________________________________________________
#  Layer (type)                                    Output Shape                                Param #
# ==============================================================================================================
#  input (InputLayer)                              [(None, None, 193)]                         0
#
#  expand_dim (Reshape)                            (None, None, 193, 1)                        0
#
#  conv_1 (Conv2D)                                 (None, None, 97, 32)                        14432
#
#  conv_1_bn (BatchNormalization)                  (None, None, 97, 32)                        128
#
#  conv_1_relu (ReLU)                              (None, None, 97, 32)                        0
#
#  conv_2 (Conv2D)                                 (None, None, 49, 32)                        236544
#
#  conv_2_bn (BatchNormalization)                  (None, None, 49, 32)                        128
#
#  conv_2_relu (ReLU)                              (None, None, 49, 32)                        0
#
#  reshape (Reshape)                               (None, None, 1568)                          0
#
#  bidirectional_1 (Bidirectional)                 (None, None, 1024)                          6395904
#
#  dropout (Dropout)                               (None, None, 1024)                          0
#
#  bidirectional_2 (Bidirectional)                 (None, None, 1024)                          4724736
#
#  dropout_1 (Dropout)                             (None, None, 1024)                          0
#
#  bidirectional_3 (Bidirectional)                 (None, None, 1024)                          4724736
#
#  dropout_2 (Dropout)                             (None, None, 1024)                          0
#
#  bidirectional_4 (Bidirectional)                 (None, None, 1024)                          4724736
#
#  dropout_3 (Dropout)                             (None, None, 1024)                          0
#
#  bidirectional_5 (Bidirectional)                 (None, None, 1024)                          4724736
#
#  dense_1 (Dense)                                 (None, None, 1024)                          1049600
#
#  dense_1_relu (ReLU)                             (None, None, 1024)                          0
#
#  dropout_4 (Dropout)                             (None, None, 1024)                          0
#
#  dense (Dense)                                   (None, None, 243)                           249075
#
# ==============================================================================================================
# Total params: 26,844,755
# Trainable params: 26,844,627
# Non-trainable params: 128
# ______________________________________________________________________________________________________________

# %%
# A utility function to decode the output of the network
def decode_batch_predictions(pred):
    input_len = np.ones(pred.shape[0]) * pred.shape[1]
    # Use greedy search. For complex tasks, you can use beam search
    results = keras.backend.ctc_decode(pred, input_length=input_len, greedy=True)[0][0]
    # Iterate over the results and get back the text
    output_text = []
    for result in results:
        result = tf.strings.reduce_join(num_to_char(result)).numpy().decode("utf-8")
        output_text.append(result)
    return output_text


# A callback class to output a few transcriptions during training
class CallbackEval(keras.callbacks.Callback):
    """Displays a batch of outputs after every epoch."""

    def __init__(self, dataset):
        super().__init__()
        self.dataset = dataset

    def on_epoch_end(self, epoch: int, logs=None):
        predictions = []
        targets = []
        for batch in self.dataset:
            X, y = batch
            batch_predictions = model.predict(X)
            batch_predictions = decode_batch_predictions(batch_predictions)
            predictions.extend(batch_predictions)
            for label in y:
                label = (
                    tf.strings.reduce_join(num_to_char(label)).numpy().decode("utf-8")
                )
                targets.append(label)
        wer_score = wer(targets, predictions)
        print("-" * 100)
        print(f"Word Error Rate: {wer_score:.4f}")
        print("-" * 100)
        for i in np.random.randint(0, len(predictions), 2):
            print(f"Target    : {targets[i]}")
            print(f"Prediction: {predictions[i]}")
            print("-" * 100)

# %%
# Define the number of epochs.
epochs = 12
# Callback function to check transcription on the val set.
validation_callback = CallbackEval(validation_dataset)
# Train the model
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=epochs,
    callbacks=[validation_callback],
)
# Out:
# Epoch 1/12
# 2022-06-09 13:31:39.048723: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8400
# 2022-06-09 13:31:40.679637: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-06-09 13:31:54.206577: W tensorflow/core/common_runtime/bfc_allocator.cc:462] Allocator (GPU_0_bfc) ran out of memory trying to allocate 194.44MiB (rounded to 203882752)requested by op CudnnRNN
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-06-09 13:31:54.206670: I tensorflow/core/common_runtime/bfc_allocator.cc:1010] BFCAllocator dump for GPU_0_bfc
# 2022-06-09 13:31:54.206710: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (256): 	Total Chunks: 91, Chunks in use: 91. 22.8KiB allocated for chunks. 22.8KiB in use in bin. 3.0KiB client-requested in use in bin.
# 2022-06-09 13:31:54.206736: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-09 13:31:54.206759: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1024): 	Total Chunks: 4, Chunks in use: 4. 4.2KiB allocated for chunks. 4.2KiB in use in bin. 3.9KiB client-requested in use in bin.
# 2022-06-09 13:31:54.206781: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2048): 	Total Chunks: 2, Chunks in use: 2. 4.0KiB allocated for chunks. 4.0KiB in use in bin. 3.8KiB client-requested in use in bin.
# 2022-06-09 13:31:54.206805: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4096): 	Total Chunks: 3, Chunks in use: 3. 12.0KiB allocated for chunks. 12.0KiB in use in bin. 12.0KiB client-requested in use in bin.
# 2022-06-09 13:31:54.206831: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8192): 	Total Chunks: 31, Chunks in use: 30. 373.0KiB allocated for chunks. 360.8KiB in use in bin. 360.0KiB client-requested in use in bin.
# 2022-06-09 13:31:54.206852: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06
I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 91285504 totalling 87.06MiB
# 2022-06-09 13:31:54.214261: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 4 Chunks of size 104065024 totalling 396.98MiB
# 2022-06-09 13:31:54.214281: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 119799808 totalling 228.50MiB
# 2022-06-09 13:31:54.214304: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 181153024 totalling 172.76MiB
# 2022-06-09 13:31:54.214323: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 9 Chunks of size 203882752 totalling 1.71GiB
# 2022-06-09 13:31:54.214342: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 206006272 totalling 392.93MiB
# 2022-06-09 13:31:54.214360: I tensorflow/core/common_runtime/bfc_allocator.cc:1078] Sum Total of in-use chunks: 4.45GiB
# 2022-06-09 13:31:54.214381: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] total_region_allocated_bytes_: 4855169024 memory_limit_: 4855169024 available bytes: 0 curr_region_allocation_bytes_: 9710338048
# 2022-06-09 13:31:54.214409: I tensorflow/core/common_runtime/bfc_allocator.cc:1086] Stats:
# Limit:                      4855169024
# InUse:                      4773646080
# MaxInUse:                   4773646080
# NumAllocs:                         770
# MaxAllocSize:               2920178176
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-06-09 13:31:54.214477: W tensorflow/core/common_runtime/bfc_allocator.cc:474] ***************************************************************************************************x
# 2022-06-09 13:31:54.214572: E tensorflow/stream_executor/dnn.cc:868] OOM when allocating tensor with shape[50970628] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 2022-06-09 13:31:54.214672: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at cudnn_rnn_ops.cc:1563 : INTERNAL: Failed to call ThenRnnForward with model config: [rnn_mode, rnn_input_mode, rnn_direction_mode]: 3, 0, 0 , [num_layers, input_size, num_units, dir_count, max_seq_length, batch_size, cell_num_units]: [1, 1024, 512, 1, 1037, 16, 0]
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# /home/teddy/dev/learning/10 academy/working/STT/notebooks/modeling_tewodros.ipynb Cell 18' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/home/teddy/dev/learning/10%20academy/working/STT/notebooks/modeling_tewodros.ipynb#ch0000016?line=3'>4</a> validation_callback = CallbackEval(validation_dataset)
#       <a href='vscode-notebook-cell:/home/teddy/dev/learning/10%20academy/working/STT/notebooks/modeling_tewodros.ipynb#ch0000016?line=4'>5</a> # Train the model
# ----> <a href='vscode-notebook-cell:/home/teddy/dev/learning/10%20academy/working/STT/notebooks/modeling_tewodros.ipynb#ch0000016?line=5'>6</a> history = model.fit(
#       <a href='vscode-notebook-cell:/home/teddy/dev/learning/10%20academy/working/STT/notebooks/modeling_tewodros.ipynb#ch0000016?line=6'>7</a>     train_dataset,
#       <a href='vscode-notebook-cell:/home/teddy/dev/learning/10%20academy/working/STT/notebooks/modeling_tewodros.ipynb#ch0000016?line=7'>8</a>     validation_data=validation_dataset,
#       <a href='vscode-notebook-cell:/home/teddy/dev/learning/10%20academy/working/STT/notebooks/modeling_tewodros.ipynb#ch0000016?line=8'>9</a>     epochs=epochs,
#      <a href='vscode-notebook-cell:/home/teddy/dev/learning/10%20academy/working/STT/notebooks/modeling_tewodros.ipynb#ch0000016?line=9'>10</a>     callbacks=[validation_callback],
#      <a href='vscode-notebook-cell:/home/teddy/dev/learning/10%20academy/working/STT/notebooks/modeling_tewodros.ipynb#ch0000016?line=10'>11</a> )
#
# File ~/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> <a href='file:///home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=66'>67</a>   raise e.with_traceback(filtered_tb) from None
#      <a href='file:///home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=67'>68</a> finally:
#      <a href='file:///home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=68'>69</a>   del filtered_tb
#
# File ~/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      <a href='file:///home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/eager/execute.py?line=51'>52</a> try:
#      <a href='file:///home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/eager/execute.py?line=52'>53</a>   ctx.ensure_initialized()
# ---> <a href='file:///home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/eager/execute.py?line=53'>54</a>   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      <a href='file:///home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/eager/execute.py?line=54'>55</a>                                       inputs, attrs, num_outputs)
#      <a href='file:///home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/eager/execute.py?line=55'>56</a> except core._NotOkStatusException as e:
#      <a href='file:///home/teddy/anaconda3/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/eager/execute.py?line=56'>57</a>   if name is not None:
#
# CancelledError: Graph execution error:
#
# RecvAsync is cancelled.
# 	 [[{{node CTCLoss/Log/_78}}]] [Op:__inference_train_function_27228]
